# %%
"""
https://www.datacamp.com/community/tutorials/time-series-analysis-tutorial
"""
# Tutorial on Sourcing, Wrangling, and Exploring Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('datacamp_facebook_live_ny_resolution-master/data/multiTimeline.csv', skiprows=1)
df.head()
# Out:
#      Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0  2004-01                100                31                    48
# 1  2004-02                 75                26                    49
# 2  2004-03                 67                24                    47
# 3  2004-04                 70                22                    48
# 4  2004-05                 72                22                    43

# %%
# Wrangling the data:
# Renaming the columns
df.columns = ['month', 'diet', 'gym', 'finance']
df.head()
# Out:
#      month  diet  gym  finance
# 0  2004-01   100   31       48
# 1  2004-02    75   26       49
# 2  2004-03    67   24       47
# 3  2004-04    70   22       48
# 4  2004-05    72   22       43

# %%
# Changing data types of columns
# (Use 'inplace=True' to alter the original index)
df.month = pd.to_datetime(df.month)
df.set_index('month', inplace=True)
df.head()
# Out:
#             diet  gym  finance
# month
# 2004-01-01   100   31       48
# 2004-02-01    75   26       49
# 2004-03-01    67   24       47
# 2004-04-01    70   22       48
# 2004-05-01    72   22       43

# %%
# EDA (Exploratory Data Analysis)
# Plotting with pandas .plot()
df.plot(figsize=(20, 10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5, 0, 'Year')
